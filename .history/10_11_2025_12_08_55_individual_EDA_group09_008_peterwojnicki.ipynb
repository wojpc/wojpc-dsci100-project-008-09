# %% [markdown]
# ## Project Planning Stage (Individual)
# ### Peter Wojnicki 78625613
#
#
# | Month    | Savings |
# | :------: | :-----: |
# | January  | $250    |
# | February | $80     |
# | March    | $420    |

# %%
### Run this cell before continuing.
library(tidyverse)
library(dplyr)

# %%
players_data <- read_csv("/home/jovyan/work/wojpc-dsci100-project-008-09/data/players.csv")
sessions_data <- read_csv("/home/jovyan/work/wojpc-dsci100-project-008-09/data/sessions.csv")

is_players_numeric <- players_data |>
    sapply(is.numeric)

players_means <- players_data[, is_players_numeric] |>
    sapply(mean)

players_means
head(players_data)
head(sessions_data)
